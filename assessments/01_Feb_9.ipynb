# %% [markdown]
# # Assessment 1 (Feb 9th)

# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://github.com/elizjo/AIT-deep-learning/edit/main/assessments/01_Feb_9.ipynb)

# %%
# !wget -P /content/drive/MyDrive/AIT_DeepLearning/collegemark-standalone.jpg https://www.pomona.edu/sites/default/files/images/insets/collegemark-standalone.jpg
# Out:
# --2023-02-15 19:04:05--  https://www.pomona.edu/sites/default/files/images/insets/collegemark-standalone.jpg
# Resolving www.pomona.edu (www.pomona.edu)... 151.101.2.133, 151.101.66.133, 151.101.130.133, ...
# Connecting to www.pomona.edu (www.pomona.edu)|151.101.2.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 49434 (48K) [image/jpeg]
# Saving to: ‘/content/drive/MyDrive/AIT_DeepLearning/collegemark-standalone.jpg/collegemark-standalone.jpg.1’
#
# collegemark-standal 100%[===================>]  48.28K  --.-KB/s    in 0.004s
#
# 2023-02-15 19:04:05 (11.1 MB/s) - ‘/content/drive/MyDrive/AIT_DeepLearning/collegemark-standalone.jpg/collegemark-standalone.jpg.1’ saved [49434/49434]

# %%
from skimage import io
 
img = io.imread("/content/drive/MyDrive/AIT_DeepLearning/collegemark-standalone.jpg/collegemark-standalone.jpg")
io.imshow(img)

# %%
# Set the first 30 lines to "black" (0), 
img[:30,-30:] = 0
io.imshow(img)
